# %%
import os
from dotenv import load_dotenv
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_anthropic import ChatAnthropic
from langchain_core.tools import tool
from langchain.callbacks.tracers import LangChainTracer
from langgraph.checkpoint.sqlite import SqliteSaver

langsmith = LangChainTracer()
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = "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"

_ = load_dotenv()

# %%
@tool
def even_handler(n: int) -> str:
    """Handle even numbers by dividing them by 2."""
    if n % 2 == 0:
        return str(n // 2)
    return "DO-NOT-KNOW"
@tool
def odd_handler(n: int) -> str:
    """Handle odd numbers by multiplying by 3 and adding 1."""
    if n % 2 != 0:
        return str(3 * n + 1)
    return "DO-NOT-KNOW"

tools = [even_handler, odd_handler]

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

# %%
class Agent:

    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_llm)
        graph.add_node("even", self.even_handler)
        graph.add_node("odd", self.odd_handler)
        graph.add_edge("even","llm")
        graph.add_edge("odd", "llm")
        graph.set_entry_point("llm")

        graph.add_conditional_edges(
            "llm",
            self.decide_action,
            {
                "even": "even",
                "odd": "odd",
                "end": END
            }
        )
        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def decide_action(self, state: AgentState):
        print("\n--- In decide_action ---")
        last_message = state['messages'][-1]
        print(f"Last message: {last_message}")
        if not last_message.tool_calls:
            print("No tool calls, ending.")
            return "end"
        
        tool_call = last_message.tool_calls[0]
        print(f"Tool call: {tool_call}")
        tool_name = tool_call.get('name')
        print(f"Tool name: {tool_name}")
        
        if tool_name == "even_handler":
            print("Decided: even")
            return "even"
        elif tool_name == "odd_handler":
            print("Decided: odd")
            return "odd"
        else:
            print("Decided: end")
            return "end"

    def call_llm(self, state: AgentState):
        print("\n--- In call_llm ---")
        messages = state['messages']
        print(f"Input messages: {messages}")
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        print(f"LLM output: {message}")
        return {'messages': [message]}

    def even_handler(self, state: AgentState):
        print("\n--- In even_handler ---")
        last_message = state['messages'][-1]
        print(f"Last message: {last_message}")
        tool_call = last_message.tool_calls[0]
        print(f"Tool call: {tool_call}")
        args = tool_call.get('args', {})
        print(f"Args: {args}")
        
        n = int(args.get('n', 0))
        print(f"Number to process: {n}")
        
        if n % 2 == 0:
            result = str(n // 2)
        else:
            result = "DO-NOT-KNOW"
        print(f"Result: {result}")
        return {'messages': [ToolMessage(content=result, name="even_handler", tool_call_id=tool_call.get('id', ''))]}
    
    def odd_handler(self, state: AgentState):
        print("\n--- In odd_handler ---")
        last_message = state['messages'][-1]
        print(f"Last message: {last_message}")
        tool_call = last_message.tool_calls[0]
        print(f"Tool call: {tool_call}")
        args = tool_call.get('args', {})
        print(f"Args: {args}")
        
        n = int(args.get('n', 0))
        print(f"Number to process: {n}")
        
        if n % 2 != 0:
            result = str(3 * n + 1)
        else:
            result = "DO-NOT-KNOW"
        print(f"Result: {result}")
        return {'messages': [ToolMessage(content=result, name="odd_handler", tool_call_id=tool_call.get('id', ''))]}

# %%
import os
load_dotenv()
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")
system_message="""
        You will receive a list of numbers from the user.
        Your goal is to apply a transformation to each number.
        However you do not know how to do this transformation. 
        You can simply send each number FROM THE GIVEN LIST
        and the tools will do the transforamtion for you
        with the appropriate transformation applied.
        IMPORTANT: only send one number at a time, concisely, say nothing else.
        Once you have accomplished your goal, say DONE and show the result.
        Start by asking the user for the list of numbers.
        Your tools will be :
        even_handler use this for even numbers
        odd_handler use this for odd numbers


        """

model = ChatAnthropic(model="claude-3-5-sonnet-20240620", anthropic_api_key=anthropic_api_key)

# %%
with SqliteSaver.from_conn_string(":memory:") as memory:
    abot = Agent(model, tools, checkpointer=memory, system=system_message)
    messages = [HumanMessage(content="1 3 6 9")]
    messages2 = [HumanMessage(content="I want to add 4 5 to the original sequence and then see what is the full transformed list")]
    
    thread = {"configurable": {"thread_id": "1"}}
    thread2 = {"configurable": {"thread_id": "2"}}
    
    for event in abot.graph.stream({"messages": messages}, thread):
        for v in event.values():
            print(v['messages'])

    for event in abot.graph.stream({"messages": messages2}, thread):
        for v in event.values():
            print(v['messages'])
            
    for event in abot.graph.stream({"messages": messages2}, thread2):
        for v in event.values():
            print(v['messages'])
# Out:
# --- In call_llm ---
# Input messages: [HumanMessage(content='1 3 6 9', additional_kwargs={}, response_metadata={})]
# LLM output: content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}} id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}] usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}
#
# --- In decide_action ---
# Last message: content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}} id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}] usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}
# Tool call: {'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}
# Tool name: odd_handler
# Decided: odd
# [AIMessage(content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}}, id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669})]
#
# --- In odd_handler ---
# Last message: content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}} id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}] usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}
# Tool call: {'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}
# Args: {'n': 1}
# Number to process: 1
# Result: 4
# [ToolMessage(content='4', name='odd_handler', tool_call_id='toolu_01DNZ33amuNJ4aT1hy6S4rJe')]
#
# --- In call_llm ---
# Input messages: [HumanMessage(content='1 3 6 9', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}}, id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}), ToolMessage(content='4', name='odd_handler', tool_call_id='toolu_01DNZ33amuNJ4aT1hy6S4rJe')]
# LLM output: content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}} id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}] usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735}
#
# --- In decide_action ---
# Last message: content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}} id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}] usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735}
# Tool call: {'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}
# Tool name: odd_handler
# Decided: odd
# [AIMessage(content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}}, id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735})]
#
# --- In odd_handler ---
# Last message: content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}} id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}] usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735}
# Tool call: {'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}
# Args: {'n': 3}
# Number to process: 3
# Result: 10
# [ToolMessage(content='10', name='odd_handler', tool_call_id='toolu_013Uod43spaXzwkaG8mMLCY3')]
#
# --- In call_llm ---
# Input messages: [HumanMessage(content='1 3 6 9', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}}, id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}), ToolMessage(content='4', name='odd_handler', tool_call_id='toolu_01DNZ33amuNJ4aT1hy6S4rJe'), AIMessage(content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}}, id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735}), ToolMessage(content='10', name='odd_handler', tool_call_id='toolu_013Uod43spaXzwkaG8mMLCY3')]
# LLM output: content=[{'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'input': {'n': 6}, 'name': 'even_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01TePui5UJdSoZNEGrFLhKm5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 747, 'output_tokens': 54}} id='run-d07f1ca7-e0b4-4986-8822-d7e768d47fe1-0' tool_calls=[{'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}] usage_metadata={'input_tokens': 747, 'output_tokens': 54, 'total_tokens': 801}
#
# --- In decide_action ---
# Last message: content=[{'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'input': {'n': 6}, 'name': 'even_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01TePui5UJdSoZNEGrFLhKm5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 747, 'output_tokens': 54}} id='run-d07f1ca7-e0b4-4986-8822-d7e768d47fe1-0' tool_calls=[{'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}] usage_metadata={'input_tokens': 747, 'output_tokens': 54, 'total_tokens': 801}
# Tool call: {'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}
# Tool name: even_handler
# Decided: even
# [AIMessage(content=[{'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'input': {'n': 6}, 'name': 'even_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01TePui5UJdSoZNEGrFLhKm5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 747, 'output_tokens': 54}}, id='run-d07f1ca7-e0b4-4986-8822-d7e768d47fe1-0', tool_calls=[{'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 747, 'output_tokens': 54, 'total_tokens': 801})]
#
# --- In even_handler ---
# Last message: content=[{'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'input': {'n': 6}, 'name': 'even_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01TePui5UJdSoZNEGrFLhKm5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 747, 'output_tokens': 54}} id='run-d07f1ca7-e0b4-4986-8822-d7e768d47fe1-0' tool_calls=[{'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}] usage_metadata={'input_tokens': 747, 'output_tokens': 54, 'total_tokens': 801}
# Tool call: {'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}
# Args: {'n': 6}
# Number to process: 6
# Result: 3
# [ToolMessage(content='3', name='even_handler', tool_call_id='toolu_01EW9KySm6NGF5ZPmvVtQzDu')]
#
# --- In call_llm ---
# Input messages: [HumanMessage(content='1 3 6 9', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}}, id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}), ToolMessage(content='4', name='odd_handler', tool_call_id='toolu_01DNZ33amuNJ4aT1hy6S4rJe'), AIMessage(content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}}, id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735}), ToolMessage(content='10', name='odd_handler', tool_call_id='toolu_013Uod43spaXzwkaG8mMLCY3'), AIMessage(content=[{'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'input': {'n': 6}, 'name': 'even_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01TePui5UJdSoZNEGrFLhKm5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 747, 'output_tokens': 54}}, id='run-d07f1ca7-e0b4-4986-8822-d7e768d47fe1-0', tool_calls=[{'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 747, 'output_tokens': 54, 'total_tokens': 801}), ToolMessage(content='3', name='even_handler', tool_call_id='toolu_01EW9KySm6NGF5ZPmvVtQzDu')]
# LLM output: content=[{'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'input': {'n': 9}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01HQkfwnzk5YQRc8Aed2kkCP', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 813, 'output_tokens': 54}} id='run-50bfb588-9b75-420b-8cc4-2f38212b9509-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}] usage_metadata={'input_tokens': 813, 'output_tokens': 54, 'total_tokens': 867}
#
# --- In decide_action ---
# Last message: content=[{'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'input': {'n': 9}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01HQkfwnzk5YQRc8Aed2kkCP', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 813, 'output_tokens': 54}} id='run-50bfb588-9b75-420b-8cc4-2f38212b9509-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}] usage_metadata={'input_tokens': 813, 'output_tokens': 54, 'total_tokens': 867}
# Tool call: {'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}
# Tool name: odd_handler
# Decided: odd
# [AIMessage(content=[{'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'input': {'n': 9}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01HQkfwnzk5YQRc8Aed2kkCP', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 813, 'output_tokens': 54}}, id='run-50bfb588-9b75-420b-8cc4-2f38212b9509-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}], usage_metadata={'input_tokens': 813, 'output_tokens': 54, 'total_tokens': 867})]
#
# --- In odd_handler ---
# Last message: content=[{'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'input': {'n': 9}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01HQkfwnzk5YQRc8Aed2kkCP', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 813, 'output_tokens': 54}} id='run-50bfb588-9b75-420b-8cc4-2f38212b9509-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}] usage_metadata={'input_tokens': 813, 'output_tokens': 54, 'total_tokens': 867}
# Tool call: {'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}
# Args: {'n': 9}
# Number to process: 9
# Result: 28
# [ToolMessage(content='28', name='odd_handler', tool_call_id='toolu_01E3UWcUcNxFJgbFX3chfRbA')]
#
# --- In call_llm ---
# Input messages: [HumanMessage(content='1 3 6 9', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}}, id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}), ToolMessage(content='4', name='odd_handler', tool_call_id='toolu_01DNZ33amuNJ4aT1hy6S4rJe'), AIMessage(content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}}, id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735}), ToolMessage(content='10', name='odd_handler', tool_call_id='toolu_013Uod43spaXzwkaG8mMLCY3'), AIMessage(content=[{'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'input': {'n': 6}, 'name': 'even_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01TePui5UJdSoZNEGrFLhKm5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 747, 'output_tokens': 54}}, id='run-d07f1ca7-e0b4-4986-8822-d7e768d47fe1-0', tool_calls=[{'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 747, 'output_tokens': 54, 'total_tokens': 801}), ToolMessage(content='3', name='even_handler', tool_call_id='toolu_01EW9KySm6NGF5ZPmvVtQzDu'), AIMessage(content=[{'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'input': {'n': 9}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01HQkfwnzk5YQRc8Aed2kkCP', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 813, 'output_tokens': 54}}, id='run-50bfb588-9b75-420b-8cc4-2f38212b9509-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}], usage_metadata={'input_tokens': 813, 'output_tokens': 54, 'total_tokens': 867}), ToolMessage(content='28', name='odd_handler', tool_call_id='toolu_01E3UWcUcNxFJgbFX3chfRbA')]
# LLM output: content='DONE\n\nThe result of applying the transformations to the list [1, 3, 6, 9] is [4, 10, 3, 28].' additional_kwargs={} response_metadata={'id': 'msg_01X47qXf8got2XuwTnidvaK8', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 879, 'output_tokens': 42}} id='run-78919150-8461-4292-b776-ceb387d232aa-0' usage_metadata={'input_tokens': 879, 'output_tokens': 42, 'total_tokens': 921}
#
# --- In decide_action ---
# Last message: content='DONE\n\nThe result of applying the transformations to the list [1, 3, 6, 9] is [4, 10, 3, 28].' additional_kwargs={} response_metadata={'id': 'msg_01X47qXf8got2XuwTnidvaK8', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 879, 'output_tokens': 42}} id='run-78919150-8461-4292-b776-ceb387d232aa-0' usage_metadata={'input_tokens': 879, 'output_tokens': 42, 'total_tokens': 921}
# No tool calls, ending.
# [AIMessage(content='DONE\n\nThe result of applying the transformations to the list [1, 3, 6, 9] is [4, 10, 3, 28].', additional_kwargs={}, response_metadata={'id': 'msg_01X47qXf8got2XuwTnidvaK8', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 879, 'output_tokens': 42}}, id='run-78919150-8461-4292-b776-ceb387d232aa-0', usage_metadata={'input_tokens': 879, 'output_tokens': 42, 'total_tokens': 921})]
#
# --- In call_llm ---
# Input messages: [HumanMessage(content='1 3 6 9', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}}, id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}), ToolMessage(content='4', name='odd_handler', tool_call_id='toolu_01DNZ33amuNJ4aT1hy6S4rJe'), AIMessage(content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}}, id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735}), ToolMessage(content='10', name='odd_handler', tool_call_id='toolu_013Uod43spaXzwkaG8mMLCY3'), AIMessage(content=[{'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'input': {'n': 6}, 'name': 'even_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01TePui5UJdSoZNEGrFLhKm5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 747, 'output_tokens': 54}}, id='run-d07f1ca7-e0b4-4986-8822-d7e768d47fe1-0', tool_calls=[{'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 747, 'output_tokens': 54, 'total_tokens': 801}), ToolMessage(content='3', name='even_handler', tool_call_id='toolu_01EW9KySm6NGF5ZPmvVtQzDu'), AIMessage(content=[{'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'input': {'n': 9}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01HQkfwnzk5YQRc8Aed2kkCP', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 813, 'output_tokens': 54}}, id='run-50bfb588-9b75-420b-8cc4-2f38212b9509-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}], usage_metadata={'input_tokens': 813, 'output_tokens': 54, 'total_tokens': 867}), ToolMessage(content='28', name='odd_handler', tool_call_id='toolu_01E3UWcUcNxFJgbFX3chfRbA'), AIMessage(content='DONE\n\nThe result of applying the transformations to the list [1, 3, 6, 9] is [4, 10, 3, 28].', additional_kwargs={}, response_metadata={'id': 'msg_01X47qXf8got2XuwTnidvaK8', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 879, 'output_tokens': 42}}, id='run-78919150-8461-4292-b776-ceb387d232aa-0', usage_metadata={'input_tokens': 879, 'output_tokens': 42, 'total_tokens': 921}), HumanMessage(content='I want to add 4 5 to the original sequence and then see what is the full transformed list', additional_kwargs={}, response_metadata={})]
# LLM output: content=[{'text': "Certainly! I'll add 4 and 5 to the original sequence and then process all the numbers, including the new ones.", 'type': 'text'}, {'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'input': {'n': 4}, 'name': 'even_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01EYUaWcq8iQcXbWK51kT6o5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 946, 'output_tokens': 82}} id='run-d65b8da0-bf13-4d15-a5f1-812b204dcd26-0' tool_calls=[{'name': 'even_handler', 'args': {'n': 4}, 'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'type': 'tool_call'}] usage_metadata={'input_tokens': 946, 'output_tokens': 82, 'total_tokens': 1028}
#
# --- In decide_action ---
# Last message: content=[{'text': "Certainly! I'll add 4 and 5 to the original sequence and then process all the numbers, including the new ones.", 'type': 'text'}, {'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'input': {'n': 4}, 'name': 'even_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01EYUaWcq8iQcXbWK51kT6o5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 946, 'output_tokens': 82}} id='run-d65b8da0-bf13-4d15-a5f1-812b204dcd26-0' tool_calls=[{'name': 'even_handler', 'args': {'n': 4}, 'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'type': 'tool_call'}] usage_metadata={'input_tokens': 946, 'output_tokens': 82, 'total_tokens': 1028}
# Tool call: {'name': 'even_handler', 'args': {'n': 4}, 'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'type': 'tool_call'}
# Tool name: even_handler
# Decided: even
# [AIMessage(content=[{'text': "Certainly! I'll add 4 and 5 to the original sequence and then process all the numbers, including the new ones.", 'type': 'text'}, {'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'input': {'n': 4}, 'name': 'even_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01EYUaWcq8iQcXbWK51kT6o5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 946, 'output_tokens': 82}}, id='run-d65b8da0-bf13-4d15-a5f1-812b204dcd26-0', tool_calls=[{'name': 'even_handler', 'args': {'n': 4}, 'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 946, 'output_tokens': 82, 'total_tokens': 1028})]
#
# --- In even_handler ---
# Last message: content=[{'text': "Certainly! I'll add 4 and 5 to the original sequence and then process all the numbers, including the new ones.", 'type': 'text'}, {'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'input': {'n': 4}, 'name': 'even_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_01EYUaWcq8iQcXbWK51kT6o5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 946, 'output_tokens': 82}} id='run-d65b8da0-bf13-4d15-a5f1-812b204dcd26-0' tool_calls=[{'name': 'even_handler', 'args': {'n': 4}, 'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'type': 'tool_call'}] usage_metadata={'input_tokens': 946, 'output_tokens': 82, 'total_tokens': 1028}
# Tool call: {'name': 'even_handler', 'args': {'n': 4}, 'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'type': 'tool_call'}
# Args: {'n': 4}
# Number to process: 4
# Result: 2
# [ToolMessage(content='2', name='even_handler', tool_call_id='toolu_01L628bpxnx8niAvbN3RfGVx')]
#
# --- In call_llm ---
# Input messages: [HumanMessage(content='1 3 6 9', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}}, id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}), ToolMessage(content='4', name='odd_handler', tool_call_id='toolu_01DNZ33amuNJ4aT1hy6S4rJe'), AIMessage(content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}}, id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735}), ToolMessage(content='10', name='odd_handler', tool_call_id='toolu_013Uod43spaXzwkaG8mMLCY3'), AIMessage(content=[{'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'input': {'n': 6}, 'name': 'even_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01TePui5UJdSoZNEGrFLhKm5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 747, 'output_tokens': 54}}, id='run-d07f1ca7-e0b4-4986-8822-d7e768d47fe1-0', tool_calls=[{'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 747, 'output_tokens': 54, 'total_tokens': 801}), ToolMessage(content='3', name='even_handler', tool_call_id='toolu_01EW9KySm6NGF5ZPmvVtQzDu'), AIMessage(content=[{'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'input': {'n': 9}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01HQkfwnzk5YQRc8Aed2kkCP', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 813, 'output_tokens': 54}}, id='run-50bfb588-9b75-420b-8cc4-2f38212b9509-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}], usage_metadata={'input_tokens': 813, 'output_tokens': 54, 'total_tokens': 867}), ToolMessage(content='28', name='odd_handler', tool_call_id='toolu_01E3UWcUcNxFJgbFX3chfRbA'), AIMessage(content='DONE\n\nThe result of applying the transformations to the list [1, 3, 6, 9] is [4, 10, 3, 28].', additional_kwargs={}, response_metadata={'id': 'msg_01X47qXf8got2XuwTnidvaK8', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 879, 'output_tokens': 42}}, id='run-78919150-8461-4292-b776-ceb387d232aa-0', usage_metadata={'input_tokens': 879, 'output_tokens': 42, 'total_tokens': 921}), HumanMessage(content='I want to add 4 5 to the original sequence and then see what is the full transformed list', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'text': "Certainly! I'll add 4 and 5 to the original sequence and then process all the numbers, including the new ones.", 'type': 'text'}, {'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'input': {'n': 4}, 'name': 'even_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01EYUaWcq8iQcXbWK51kT6o5', 'model': 'claude-3-5-sonnet ...
# LLM output: content=[{'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'input': {'n': 5}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_012bfCa6dGjVXnFkhymKh9uq', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 1041, 'output_tokens': 54}} id='run-ce1a0ef6-8df6-4cb7-a26a-3c4bccec3f76-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 5}, 'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1041, 'output_tokens': 54, 'total_tokens': 1095}
#
# --- In decide_action ---
# Last message: content=[{'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'input': {'n': 5}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_012bfCa6dGjVXnFkhymKh9uq', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 1041, 'output_tokens': 54}} id='run-ce1a0ef6-8df6-4cb7-a26a-3c4bccec3f76-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 5}, 'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1041, 'output_tokens': 54, 'total_tokens': 1095}
# Tool call: {'name': 'odd_handler', 'args': {'n': 5}, 'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'type': 'tool_call'}
# Tool name: odd_handler
# Decided: odd
# [AIMessage(content=[{'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'input': {'n': 5}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_012bfCa6dGjVXnFkhymKh9uq', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 1041, 'output_tokens': 54}}, id='run-ce1a0ef6-8df6-4cb7-a26a-3c4bccec3f76-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 5}, 'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1041, 'output_tokens': 54, 'total_tokens': 1095})]
#
# --- In odd_handler ---
# Last message: content=[{'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'input': {'n': 5}, 'name': 'odd_handler', 'type': 'tool_use'}] additional_kwargs={} response_metadata={'id': 'msg_012bfCa6dGjVXnFkhymKh9uq', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 1041, 'output_tokens': 54}} id='run-ce1a0ef6-8df6-4cb7-a26a-3c4bccec3f76-0' tool_calls=[{'name': 'odd_handler', 'args': {'n': 5}, 'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1041, 'output_tokens': 54, 'total_tokens': 1095}
# Tool call: {'name': 'odd_handler', 'args': {'n': 5}, 'id': 'toolu_018donuNebS8CNqBJKJAkhFK', 'type': 'tool_call'}
# Args: {'n': 5}
# Number to process: 5
# Result: 16
# [ToolMessage(content='16', name='odd_handler', tool_call_id='toolu_018donuNebS8CNqBJKJAkhFK')]
#
# --- In call_llm ---
# Input messages: [HumanMessage(content='1 3 6 9', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'text': "Thank you for providing the list of numbers: 1, 3, 6, and 9. I'll now process each number using the appropriate handler function.", 'type': 'text'}, {'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'input': {'n': 1}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_014KsYaXUfogG3bvxoy2eZBH', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 581, 'output_tokens': 88}}, id='run-9382b590-e325-4b6a-a1ed-4fb135b6b0ad-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 1}, 'id': 'toolu_01DNZ33amuNJ4aT1hy6S4rJe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 581, 'output_tokens': 88, 'total_tokens': 669}), ToolMessage(content='4', name='odd_handler', tool_call_id='toolu_01DNZ33amuNJ4aT1hy6S4rJe'), AIMessage(content=[{'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'input': {'n': 3}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01QpwUw6FqpMtBXYSFvsx8w1', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 681, 'output_tokens': 54}}, id='run-42553b60-3ce5-4a04-8dd0-7a0b449b31db-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 3}, 'id': 'toolu_013Uod43spaXzwkaG8mMLCY3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 681, 'output_tokens': 54, 'total_tokens': 735}), ToolMessage(content='10', name='odd_handler', tool_call_id='toolu_013Uod43spaXzwkaG8mMLCY3'), AIMessage(content=[{'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'input': {'n': 6}, 'name': 'even_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01TePui5UJdSoZNEGrFLhKm5', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 747, 'output_tokens': 54}}, id='run-d07f1ca7-e0b4-4986-8822-d7e768d47fe1-0', tool_calls=[{'name': 'even_handler', 'args': {'n': 6}, 'id': 'toolu_01EW9KySm6NGF5ZPmvVtQzDu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 747, 'output_tokens': 54, 'total_tokens': 801}), ToolMessage(content='3', name='even_handler', tool_call_id='toolu_01EW9KySm6NGF5ZPmvVtQzDu'), AIMessage(content=[{'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'input': {'n': 9}, 'name': 'odd_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01HQkfwnzk5YQRc8Aed2kkCP', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'input_tokens': 813, 'output_tokens': 54}}, id='run-50bfb588-9b75-420b-8cc4-2f38212b9509-0', tool_calls=[{'name': 'odd_handler', 'args': {'n': 9}, 'id': 'toolu_01E3UWcUcNxFJgbFX3chfRbA', 'type': 'tool_call'}], usage_metadata={'input_tokens': 813, 'output_tokens': 54, 'total_tokens': 867}), ToolMessage(content='28', name='odd_handler', tool_call_id='toolu_01E3UWcUcNxFJgbFX3chfRbA'), AIMessage(content='DONE\n\nThe result of applying the transformations to the list [1, 3, 6, 9] is [4, 10, 3, 28].', additional_kwargs={}, response_metadata={'id': 'msg_01X47qXf8got2XuwTnidvaK8', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 879, 'output_tokens': 42}}, id='run-78919150-8461-4292-b776-ceb387d232aa-0', usage_metadata={'input_tokens': 879, 'output_tokens': 42, 'total_tokens': 921}), HumanMessage(content='I want to add 4 5 to the original sequence and then see what is the full transformed list', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'text': "Certainly! I'll add 4 and 5 to the original sequence and then process all the numbers, including the new ones.", 'type': 'text'}, {'id': 'toolu_01L628bpxnx8niAvbN3RfGVx', 'input': {'n': 4}, 'name': 'even_handler', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01EYUaWcq8iQcXbWK51kT6o5', 'model': 'claude-3-5-sonnet ...
# LLM output: content="Now, I'll combine these results with the previous ones to give you the full transformed list.\n\nDONE\n\nThe full original sequence is now [1, 3, 6, 9, 4, 5], and the corresponding transformed list is [4, 10, 3, 28, 2, 16].\n\nTo break it down:\n1 -> 4\n3 -> 10\n6 -> 3\n9 -> 28\n4 -> 2\n5 -> 16\n\nThis is the complete transformed list based on the updated sequence you provided." additional_kwargs={} response_metadata={'id': 'msg_01QqfVTAY7EQhJMMRDzh8Sa8', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 1107, 'output_tokens': 132}} id='run-4866e971-e993-4105-9ac9-6b97fb93ebe8-0' usage_metadata={'input_tokens': 1107, 'output_tokens': 132, 'total_tokens': 1239}
#
# --- In decide_action ---
# Last message: content="Now, I'll combine these results with the previous ones to give you the full transformed list.\n\nDONE\n\nThe full original sequence is now [1, 3, 6, 9, 4, 5], and the corresponding transformed list is [4, 10, 3, 28, 2, 16].\n\nTo break it down:\n1 -> 4\n3 -> 10\n6 -> 3\n9 -> 28\n4 -> 2\n5 -> 16\n\nThis is the complete transformed list based on the updated sequence you provided." additional_kwargs={} response_metadata={'id': 'msg_01QqfVTAY7EQhJMMRDzh8Sa8', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 1107, 'output_tokens': 132}} id='run-4866e971-e993-4105-9ac9-6b97fb93ebe8-0' usage_metadata={'input_tokens': 1107, 'output_tokens': 132, 'total_tokens': 1239}
# No tool calls, ending.
# [AIMessage(content="Now, I'll combine these results with the previous ones to give you the full transformed list.\n\nDONE\n\nThe full original sequence is now [1, 3, 6, 9, 4, 5], and the corresponding transformed list is [4, 10, 3, 28, 2, 16].\n\nTo break it down:\n1 -> 4\n3 -> 10\n6 -> 3\n9 -> 28\n4 -> 2\n5 -> 16\n\nThis is the complete transformed list based on the updated sequence you provided.", additional_kwargs={}, response_metadata={'id': 'msg_01QqfVTAY7EQhJMMRDzh8Sa8', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 1107, 'output_tokens': 132}}, id='run-4866e971-e993-4105-9ac9-6b97fb93ebe8-0', usage_metadata={'input_tokens': 1107, 'output_tokens': 132, 'total_tokens': 1239})]
#
# --- In call_llm ---
# Input messages: [HumanMessage(content='I want to add 4 5 to the original sequence and then see what is the full transformed list', additional_kwargs={}, response_metadata={})]
# LLM output: content="Certainly! I understand that you want to add the numbers 4 and 5 to the original sequence and then see the full transformed list. To do this, I'll need to know what the original sequence was. Could you please provide me with the original list of numbers? Once I have that information, I can add 4 and 5 to it and then apply the transformations using the appropriate tools." additional_kwargs={} response_metadata={'id': 'msg_01CuHDSHAundqnmQESVoK2M7', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 595, 'output_tokens': 90}} id='run-85f7391c-66c6-4ae4-a8f3-857f03812971-0' usage_metadata={'input_tokens': 595, 'output_tokens': 90, 'total_tokens': 685}
#
# --- In decide_action ---
# Last message: content="Certainly! I understand that you want to add the numbers 4 and 5 to the original sequence and then see the full transformed list. To do this, I'll need to know what the original sequence was. Could you please provide me with the original list of numbers? Once I have that information, I can add 4 and 5 to it and then apply the transformations using the appropriate tools." additional_kwargs={} response_metadata={'id': 'msg_01CuHDSHAundqnmQESVoK2M7', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 595, 'output_tokens': 90}} id='run-85f7391c-66c6-4ae4-a8f3-857f03812971-0' usage_metadata={'input_tokens': 595, 'output_tokens': 90, 'total_tokens': 685}
# No tool calls, ending.
# [AIMessage(content="Certainly! I understand that you want to add the numbers 4 and 5 to the original sequence and then see the full transformed list. To do this, I'll need to know what the original sequence was. Could you please provide me with the original list of numbers? Once I have that information, I can add 4 and 5 to it and then apply the transformations using the appropriate tools.", additional_kwargs={}, response_metadata={'id': 'msg_01CuHDSHAundqnmQESVoK2M7', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 595, 'output_tokens': 90}}, id='run-85f7391c-66c6-4ae4-a8f3-857f03812971-0', usage_metadata={'input_tokens': 595, 'output_tokens': 90, 'total_tokens': 685})]

# %% [markdown]
# ## Streaming tokens

# %%
from langgraph.checkpoint.sqlite.aio import AsyncSqliteSaver

with AsyncSqliteSaver.from_conn_string(":memory:") as memory:
    abot = Agent(model, tools, checkpointer=memory, system=system_message)
    messages = [HumanMessage(content="1 3 6 9")]
    thread = {"configurable": {"thread_id": "4"}}
    async for event in abot.graph.astream_events({"messages": messages}, thread, version="v1"):
        kind = event["event"]
        if kind == "on_chat_model_stream":
            content = event["data"]["chunk"].content
            if content:
                # Empty content in the context of OpenAI means
                # that the model is asking for a tool to be invoked.
                # So we only print non-empty content
                print(content, end="|")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 from langgraph.checkpoint.sqlite.aio import AsyncSqliteSaver
# ----> 3 with AsyncSqliteSaver.from_conn_string(":memory:") as memory:
#       4     abot = Agent(model, tools, checkpointer=memory, system=system_message)
#       5     messages = [HumanMessage(content="1 3 6 9")]
#
# TypeError: '_AsyncGeneratorContextManager' object does not support the context manager protocol

# %%
async def stream_tokens():
    print("="*50)
    print("Streaming tokens")
    print("="*50)

    memory = AsyncSqliteSaver.from_conn_string(":memory:")
    abot = Agent(model, tools, system=system_message, checkpointer=memory)

    messages = [HumanMessage(content="1 3 5")]
    thread = {"configurable": {"thread_id": "4"}}
    async for event in abot.graph.astream_events({"messages": messages}, thread, version="v1"):
        kind = event["event"]
        if kind == "on_chat_model_stream":
            content = event["data"]["chunk"].content
            if content:
                print(content, end="|")

# %%
import asyncio

asyncio.run(stream_tokens())
# Out:
# c:\Egyetem\7Felev\Szakdolgozat\number_game\.venv\Lib\site-packages\pygments\regexopt.py:77: RuntimeWarning: coroutine 'stream_tokens' was never awaited
#   '|'.join(regex_opt_inner(list(group[1]), '')
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 3
#       1 import asyncio
# ----> 3 asyncio.run(stream_tokens())
#
# File C:\Program Files\Python312\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
